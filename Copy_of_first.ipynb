# %% [markdown]
# <a href="https://colab.research.google.com/github/nitya1195/Aryan_1234/blob/main/Copy_of_first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("VASUDHAIVA KUTUMBAKAM")
# Out:
# VASUDHAIVA KUTUMBAKAM

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = mpimg.imread('/content/drive/MyDrive/earth.png')

# %%
img.shape
# Out:
# (600, 1200, 3)

# %% [markdown]
# IT IS A RGB IMAGE

# %%
img[0].shape
# Out:
# (1200, 3)

# %%
imgplot = plt.imshow(img)          # it is for visualising the image

# %%
img      #it shows it is an numpy array of three dimentions
# Out:
# array([[[0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         ...,
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ]],
#
#        [[0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         ...,
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ]],
#
#        [[0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         ...,
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ],
#         [0.03921569, 0.03921569, 0.2       ]],
#
#        ...,
#
#        [[0.8117647 , 0.7764706 , 0.7372549 ],
# ...

# %% [markdown]
# **APPLYING PSEUDOCODE SCHEEMES TO IMAGE PLOTS**
#
# Pseudocode can be a useful tool for inhancing contrast and visualising your data more easily .
# Pseudocode is relevent to single channel,greyscale

# %%
img.shape
# Out:
# (600, 1200, 3)

# %% [markdown]
# **INSTED OF WATCHING ALL BANDS TOGETHER IF YOU WANT TO VISUALISE ONLY SINGLE BAND THEN WE USE SLICING**

# %%
red_data = img[:,:,0]

# %%
red_data.shape
# Out:
# (600, 1200)

# %%
plt.imshow(red_data)

# %%
#if you want to see it in different colour band then
plt.imshow(red_data,cmap="gray")

# %%
plt.close()

# %% [markdown]
# **COLOR SCALE REFERENCE**

# %%
plt.imshow(red_data,cmap="gray")
plt.colorbar()             #this is for getting scale at right side which shows different values at different color

# %%
#FOR OBSERVING ALL THE BANDS TOGETHER

plt.figure(figsize=(15,20))
plt.subplot(1,3,1)         #subplot break the contrast into 1 row and three coloumns and out of it take 1st
plt.imshow(img[:,:,0],cmap='gray')

plt.subplot(1,3,2)
plt.imshow(img[:,:,1],cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img[:,:,2],cmap='gray')

# %%
plt.figure(figsize=(15,20))
plt.subplot(3,1,1)         #subplot break the contrast into 3 row and 1 coloumn and out of it take 1st
plt.imshow(img[:,:,0],cmap='gray')

plt.subplot(3,1,2)
plt.imshow(img[:,:,1],cmap='gray')

plt.subplot(3,1,3)
plt.imshow(img[:,:,2],cmap='gray')

# %% [markdown]
# FOR CHANGING THE SIZE

# %%
plt.figure(figsize=(5,15))        # do change here
plt.subplot(3,1,1)
plt.imshow(img[:,:,0],cmap='gray')

plt.subplot(3,1,2)
plt.imshow(img[:,:,1],cmap='gray')

plt.subplot(3,1,3)
plt.imshow(img[:,:,2],cmap='gray')
